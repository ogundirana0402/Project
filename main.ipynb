# %%
import numpy as np
import pandas as pd

# %%
#df = pd.read_csv('pan12-training.csv')
df = pd.read_csv('data/pan12-test.csv')

# %%
df.head(50)
# Out:
#                                   id  line                            author  \
# 0   affc2df0951b733d14ba92d19d9b7695     1  0a39f78bcb297ab0ebe8a29c28bfed89
# 1   affc2df0951b733d14ba92d19d9b7695     2  60659cfda992013e610f285c46692d28
# 2   affc2df0951b733d14ba92d19d9b7695     3  b8810fee2f4a71f849f3f7409546d1d9
# 3   affc2df0951b733d14ba92d19d9b7695     4  60659cfda992013e610f285c46692d28
# 4   affc2df0951b733d14ba92d19d9b7695     5  60659cfda992013e610f285c46692d28
# 5   affc2df0951b733d14ba92d19d9b7695     6  60659cfda992013e610f285c46692d28
# 6   affc2df0951b733d14ba92d19d9b7695     7  b8810fee2f4a71f849f3f7409546d1d9
# 7   affc2df0951b733d14ba92d19d9b7695     8  60659cfda992013e610f285c46692d28
# 8   affc2df0951b733d14ba92d19d9b7695     9  60659cfda992013e610f285c46692d28
# 9   affc2df0951b733d14ba92d19d9b7695    10  60659cfda992013e610f285c46692d28
# 10  affc2df0951b733d14ba92d19d9b7695    11  b8810fee2f4a71f849f3f7409546d1d9
# ...

# %%
# print(len(df.author))
print(len(df.id))
sample = list(df.id)
# Out:
# 1048575

# %%
u,f = np.unique(sample, return_counts = True)
# u,f = np.unique(df.author, return_counts = True)

# %%
print(u)
print(f)
# Out:
# ['000161e288cf8dfc468fe86d6d4af2d4' '00018fac56b9cbb5e7c6f2024c92479d'
#  '0002de15312dc33d78b6e9e4b5f61f1f' ... 'fffd9ce69d28d71b407c6ae24c3973e6'
#  'ffff2d0e314610b1df596482d806ada9' 'nan']
# [ 5  5  4 ... 46 28 53]

# %%
print(len(u))
# Out:
# 97689

# %%
#df1 = pd.read_csv('sexual-predator-ids.csv')
df1 = pd.read_csv('sexual-predator-ids-test.csv')

# %%
df1.head()
# Out:
#                         Predator_ID
# 0  fadde1cb70225e72e78a5836425471f5
# 1  54b595f1920b5b1988e907ea693303b4
# 2  c483a618171c8a6bd691ea7f238f8e02
# 3  398cab8240d8a5a9f5f201115c0337c6
# 4  d2cd98d625d8f8d91f78497efd39a74f

# %%
print(len(df1.Predator_ID))
# Out:
# 254

# %%
df["class"] = [0] * len(df.author)
df.head(150)
# Out:
#                                    id  line                            author  \
# 0    affc2df0951b733d14ba92d19d9b7695     1  0a39f78bcb297ab0ebe8a29c28bfed89
# 1    affc2df0951b733d14ba92d19d9b7695     2  60659cfda992013e610f285c46692d28
# 2    affc2df0951b733d14ba92d19d9b7695     3  b8810fee2f4a71f849f3f7409546d1d9
# 3    affc2df0951b733d14ba92d19d9b7695     4  60659cfda992013e610f285c46692d28
# 4    affc2df0951b733d14ba92d19d9b7695     5  60659cfda992013e610f285c46692d28
# ..                                ...   ...                               ...
# 145  17784c5a093477c1706b1a68cea7c802    54  fcfda042c76436b97eca32b6c0490d1d
# 146  17784c5a093477c1706b1a68cea7c802    55  713349f3afa2dbe352d2abe4d3f01a12
# 147  17784c5a093477c1706b1a68cea7c802    56  713349f3afa2dbe352d2abe4d3f01a12
# 148  17784c5a093477c1706b1a68cea7c802    57  fcfda042c76436b97eca32b6c0490d1d
# 149  17784c5a093477c1706b1a68cea7c802    58  fcfda042c76436b97eca32b6c0490d1d
#
# ...

# %%
df2 = df.loc[df.author.isin(list(df1.Predator_ID)), "class"] = 1

# %%
list1 = list(df.author)
list2 = list(df1.predator_ID)

# %%
df["class"]
# Out:
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#           ..
# 1048570    0
# 1048571    0
# 1048572    0
# 1048573    0
# 1048574    0
# Name: class, Length: 1048575, dtype: int64

# %%
u,f = np.unique(df["class"], return_counts = True)
print(u)
print(f)
# Out:
# [0 1]
# [1016671   31904]

# %%
for i in list1:
    if i in list2:
        df.loc[df.author == i, "class"] = 1

# %%
df.to_csv("pan12-ID-test.csv", index =False)

# %%
df.head(20)
# Out:
#                                   id  line                            author  \
# 0   affc2df0951b733d14ba92d19d9b7695     1  0a39f78bcb297ab0ebe8a29c28bfed89
# 1   affc2df0951b733d14ba92d19d9b7695     2  60659cfda992013e610f285c46692d28
# 2   affc2df0951b733d14ba92d19d9b7695     3  b8810fee2f4a71f849f3f7409546d1d9
# 3   affc2df0951b733d14ba92d19d9b7695     4  60659cfda992013e610f285c46692d28
# 4   affc2df0951b733d14ba92d19d9b7695     5  60659cfda992013e610f285c46692d28
# 5   affc2df0951b733d14ba92d19d9b7695     6  60659cfda992013e610f285c46692d28
# 6   affc2df0951b733d14ba92d19d9b7695     7  b8810fee2f4a71f849f3f7409546d1d9
# 7   affc2df0951b733d14ba92d19d9b7695     8  60659cfda992013e610f285c46692d28
# 8   affc2df0951b733d14ba92d19d9b7695     9  60659cfda992013e610f285c46692d28
# 9   affc2df0951b733d14ba92d19d9b7695    10  60659cfda992013e610f285c46692d28
# 10  affc2df0951b733d14ba92d19d9b7695    11  b8810fee2f4a71f849f3f7409546d1d9
# ...

# %%
df["class"]
# Out:
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#           ..
# 1048570    0
# 1048571    0
# 1048572    0
# 1048573    0
# 1048574    0
# Name: class, Length: 1048575, dtype: int64

# %%
u,f = np.unique(df["class"], return_counts = True)

# %%
print(u)
# Out:
# [0 1]

# %%
print(f)
# Out:
# [1048462     113]
